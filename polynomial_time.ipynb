# %% [markdown]
# # The Polynomial Time Complexity Class (P)
# ***
# ### Introduction
# The complexity class P refers to a collection of decision problems that can be **easily checked or solved** by an algorithm within a **polynomial amount of time**. This implies that the running time of the algorithm **increases proportionally** to a polynomial function of the *input size*. As a result, polynomial time algorithms are typically deemed as **efficient**.
#
# In computational complexity theory, P is a *fundamental complexity class* that includes many significant problems in computer science and mathematics, such as addition, sorting, searching, and matrix multiplication.
#
# P is a *subset of NP*, which involves problems that can be verified within a polynomial amount of time but might **not** necessarily be solved in polynomial time. The relationship between P and NP is a *major unresolved issue* in theoretical computer science, known as the **P vs NP problem**.
#
# References: __[Complexity Classes P and NP](http://mercury.webster.edu/aleshunas/Support%20Materials/Presentations/Complexity%20Classes%20P%20and%20NP%20(13%20sep%2006).pdf), [P (complexity)
# ](https://en.wikipedia.org/wiki/P_(complexity)), [The Aged P versus NP Problem](https://towardsdatascience.com/the-aged-p-versus-np-problem-91c2bd5dce23)__
#
# ## Complexity Classes
# ***
#
# <img src="https://ds055uzetaobb.cloudfront.net/brioche/uploads/FxkP3uKATb-complexity.jpg?width=1200" width=300 height=300 />
#
# As shown, there are many complexity classes other than P and NP that each corresponds to *certain computational problems* with related **complexity and resources** required. **Time and space** are commonly used to determine how complex a problem is. *Time complexity* is used to indicate the number of steps required to solve a problem and to verify the answer. On the other hand, *space complexity* describes the amount of memory needed for the algorithm to function.
#
# ### Types of Complexity Classes
#
# <img src="https://ds055uzetaobb.cloudfront.net/brioche/uploads/p5RvwYnzMO-aaa.png?width=1200" width=400 height=400 />
#
# In this context, *four* common complexity classes will be discussed further:
#
# - **P**: The term P in P class stands for **Polynomial Time**. This class contains decision problems (with a "yes" or "no" answer) that can be *solved* in *polynomial Turing machine*, also known as *deterministic Turing machine*. As mentioned previously, P class problems have solutions that are **easily obtainable** and can be **verified easily**.
# - **NP**: The Non-deterministic Polynomial Time class comprises decision problems that can be solved in a *non-deterministic Turing machine in polynomial time* or in a *deterministic Turing machine in exponential time*. In NP class, computational problems **cannot be solved easily** but can be **verified easily** in polynomial time. For instance, graph isomorphism is a NP class problem as it is still unsolvable in polynomial time and can be solved using *brute-force approach* which takes exponential time. A demonstration can be found in [this jupyter notebook](https://github.com/gabhang/graph_theory/blob/main/graph-isomorphism.ipynb) which discusses **P vs NP problem** as well.
# - **NP-Complete**: NP-Complete problems are **both NP and NP-Hard**. Problems in NP-Complete class are the difficult ones in NP class. Therefore, if any of the problems in NP-Complete can be solved in polynomial time, it would imply that all problems in NP class can be solved in polynomial time too.
# - **NP-Hard**: A problem that is classfied as NP-hard is **at least as difficult** as the problem in NP class. It is vital to note that *not* all NP-Hard problems are in NP as visualised in the figure above. It takes a big amount of time to verify if an NP-hard problem is right or not.
#
# References: __[Complexity Classes](https://brilliant.org/wiki/complexity-classes/), [Types of Complexity Classes | P, NP, CoNP, NP hard and NP completed](https://www.geeksforgeeks.org/types-of-complexity-classes-p-np-conp-np-hard-and-np-complete/)__
#
# ## Polynomial
# ***
# A problem that is capable of being solved in polynomial time has a complexity of $O(n^{k})$ where $k$ is a **constant non-negative integer** ($k > 0$) and $n$ is the **input**. It is also polynomial if the *time it takes to solve a problem* is **proportional** to the *size of the input size*.
#
# As previously stated, all polynomial computational problem can be solved by using a *deterministic Turing machine*, which will be further discussed in the later section.
#
# To better understand polynomial runtime, the figure below shows examples of polynomial functions.

# %%
# Polynomial functions.
import matplotlib.pyplot as plt
import numpy as np

# Create a figure.
fig, ax = plt.subplots(figsize=(12, 6))

# 1000 n values ranging between 0 to 20.
n = np.linspace(0, 20, 1000)

# Plot polynomial functions.
ax.plot(n, n**2, label="$n^2$")
ax.plot(n, n**3, label="$n^3$")
ax.plot(n, n**5, label="$n^5$")
ax.plot(n, n**10, label="$n^{10}$")

# Legend.
ax.legend()

# Show figure with limits on both x-axis and y-axis.
plt.xlim([0, 5])
plt.ylim([0, 10])
plt.show();

# %% [markdown]
# Polynomial functions are considered **efficient** because their *growth rates* are reasonable. In contrast, the growth rate of non-polynomial functions such as *exponential* and *factorial* functions, **double** with each increase in input size, making them very **inefficient**.
#
# The figure below contrasts growth rates of polynomial functions (in green) and exponential functions (in purple).

# %%
# Comparing polynomial (green) and 
# non-polynomial/exponential (purple) functions.

# Create a figure.
fig, ax = plt.subplots(figsize=(12, 6))

# 1000 n values ranging between 0 to 20.
n = np.linspace(0, 20, 1000)

# Plot polynomial functions.
ax.plot(n, n**2, label="$n^2$", color='green')
ax.plot(n, n**3, label="$n^3$", color='green')

# Plot exponential functions
ax.plot(n, 2**n, label="$2^n$", color='purple')
ax.plot(n, 3**n, label="$3^n$", color='purple')

# Legend.
ax.legend()

# Show figure with limits on both x-axis and y-axis.
plt.xlim([0, 15])
plt.ylim([0, 1500])
plt.show();

# %% [markdown]
# Although a **non-polynomial function** may be **more efficient initially** as it **starts out small** as shown above, it will **eventually surpass** the polynomial function and continue to grow *rapidly* and *exponentially* with each increase in input size. Therefore, if a decision problem can be solved in polynomial time, it is considered **fast** and **efficient**.
#
# References: __[Polynomial Time](https://mathworld.wolfram.com/PolynomialTime.html), [Exponential Functions: Introduction](https://www.purplemath.com/modules/expofcns.htm#:~:text=How%20does%20exponential%20growth%20compare,be%20bigger%20than%20the%20polynomial.), [Polynomial complexity](https://mathwiki.cs.ut.ee/asymptotics/05_polynomial_complexity)__
#
# ## Formal language
# ***
#
# Before moving into Turing machine section, it is crucial to first understand what formal language is.
#
# A formal language is an abstract language that contains *a collection of* **strings**, where each string is made up of symbols that are part of a *finite set of symbols* known as an **alphabet**. Formal languages are **generated** by *a set of rules* or by *a formal machine*, for example, *a Turing machine*, which also **identifies** formal languages.
#
# ### Alphabets
#
# Alphabets are **finite sets of symbols** that make up a *string*. For instance, alphabet {1, 2} can be used to construct strings like "1", "12", "1212", etc. It is vital to note that *space* (" ") is also considered as a symbol which is part of an alphabet.
#
# ### Strings
#
# A string contains a **finite sequence of symbols** drawn from an *alphabet* as mentioned in the previous section. A string must have a **definite length**, since it is considered 'finite' by definition. However, it may also be *empty*, with no symbols at all.
#
# The code example below illustrates the concept of strings and their length (alphabet numbers).

# %%
# Strings example.
x = ""
y = "123"
z = "Hello World!"

# Print String x, y, and z and their length.
print("Length of string x: " + str(len(x)) + ".")
print("Length of string y: " + str(len(y)) + ".")
print("Length of string z: " + str(len(z)) + ".")
# Out:
# Length of string x: 0.
# Length of string y: 3.
# Length of string z: 12.

# %% [markdown]
# ### Formal Language
#
# A formal language is a set of **finite sequence of symbols (strings)**  that are selected from a **finite set of symbols (alphabet)**.
#
# The following code shows examples of what formal language is.

# %%
# Language examples.

A = {'11', '12', '21', '22'}
B = {'AAA', 'BBB', 'AAB', 'ABA', 'ABB', 'BAA', 'BAB', 'BBA'}

print(A)
print(B)
# Out:
# {'21', '22', '11', '12'}
# {'BAB', 'BAA', 'AAB', 'ABA', 'BBA', 'AAA', 'ABB', 'BBB'}

# %% [markdown]
# Formal languages are very important in various areas such as mathematics, linguistics and specifically computer science. This is due to the fact that formal language is used in the *form of programming languages*, which are used to *construct algorithms* or to *write software programmes*.
#
# As mentioned previously, a formal language can be **defined** by **specifying a set of rules** with syntax and semantics. These rules usually uses grammars like context-free grammar. For examples, programming languages or markup languages, which are categorised under formal languages, are defined using context-free grammars.
#
# *Finite automatons*, *pushdown automatons* and *Turing machines* are examples of **formal machines** that can **create** formal languages and **identify** them. Each formal machine has its own set of rules and functions to process inputs with different computational power as shown figure below. To give an example, a finite automaton can only recognise regular languages which is a subset of formal languages whereas a Turing machine can identify any languages with its strong computational power.
#
# <img src="https://www.cs.rochester.edu/u/brown/173/lectures/flat/formal_lang/figs/automataVenn.jpg" width=400 height=400 />
#
# References: __[Formal Languages](https://chortle.ccsu.edu/finiteautomata/Section01/sect01_17.html#:~:text=All%20programming%20languages%2C%20like%20Java,machine%20language%20of%20the%20processor), [Formal Languages](http://www.cs.ucc.ie/~dgb/courses/toc/handout7.pdf), [Formal Language](https://www.sciencedirect.com/topics/computer-science/formal-language), [Formal language](https://www.alexanderthamm.com/en/data-science-glossar/formal-language/), [Formal Languages and Automata theory](https://www.cs.rochester.edu/u/brown/173/lectures/flat/formal_lang/FARE_intro1.html)__

# %% [markdown]
# ## Turing Machines
# ***
#
# Turing machines are very powerful as they act and solve problems **almost exactly like actual computers**. Any algorithm or computational problem can be **realised** or **simulated** with Turing machines, making them the **most widely used** general model of computation.
#
# *In this context, all Turing machines mentioned are deterministic as they solve problems in polynomial time, which is the main topic of this research.
#
# A Turing machine consists of an **infinitely long tape**, which **splits into cells** that represent memory spaces in a computer. Each cell contains **a symbol** from a finite set of symbols (alphabets) (usually " ", "0" or "1") with a **head** that can move *left* or *right*. The head can perform three simple tasks on *one cell at a time*:
#
# 1. Read symbol from a cell
# 2. Edit/Write a cell
# 3. Move left or right
#
# The illustration below visualises a Turing machine carrying out tasks.
#
# ![](https://cdn-wordpress-info.futurelearn.com/info/wp-content/uploads/Turing_machines_01-1.gif)

# %% [markdown]
# ### State table
#
# A Turing machine has to have a state table, which can be understood as **a set of rules or instructions to execute a program**. A state table usually has multiple states to carry out a problem. The head of a Turing machine will carry out some tasks or instructions based on the current state and symbol determined by **a finite state control**. A finite state control basically interprets the information in a state table and moves the head.
#
# The graphic below demonstrates how a Turing machine works with some simple instructions.
#
# ![](https://cdn-wordpress-info.futurelearn.com/info/wp-content/uploads/Turing_machines_05-1.gif)
#
# At first, the head reads the first symbol, which is "0". Based on the instructions, it should write a "1" and move left. Then, the head reads a "1" which then write a "0" and move to the left. The same process occurs for the next input symbol as it is also a "1". Finally, the program stops when it reads a blank symbol. At this point, the head writes nothing and does not move.
#
# The table above can represent a state in a state table. State tables consist of *multiple states*, which will be demonstrated in the next section through Python code.
#
# As a **state table is fixed** throughout the process, it can be said that **the output is predetermined by the input**.
#
# References: __[Computation and Automata](https://books.google.ie/books?hl=en&lr=&id=IblDi626fBAC&oi=fnd&pg=PP11&dq=computation+and+automata+arto+salomaa&ots=PH0L5UqOaf&sig=iTTrUiuw9va78rUahDeKA9YB2yY&redir_esc=y#v=onepage&q=computation%20and%20automata%20arto%20salomaa&f=false), [Turing Machines Explained](https://www.futurelearn.com/info/courses/how-computers-work/0/steps/49259), [Raspberry Pi](https://www.cl.cam.ac.uk/projects/raspberrypi/tutorials/turing-machine/one.html)__
#
# ### Turing Machine Code Demonstration
#
# The Python code below shows how a Turing machine works with reference of this state table:
#
# | **State** | **Symbol** | **Write** | **Move** | **Next State** |
# | :-: | :-: | :-: | :-: | :-: |
# | A | Blank | Blank | Left | B |
# | A | 0 | 0 | Right | A |
# | A | 1 | 1 | Right | A |
# |  |  |  |  |  |
# | B | Blank | 1 | Right | C |
# | B | 0 | 1 | Left | C |
# | B | 1 | 0 | Left | B |
# |  |  |  |  |  |
# | C | Blank | Blank | Left | Halt |
# | C | 0 | 0 | Right | C |
# | C | 1 | 1 | Right | C |
#
# Initially, The Turing machine starts in state A. It reads the first symbol and carries out write and move tasks accordingly. The Turing machine continues to execute until the state reaches 'HALT'. At that point the function returns the output.

# %%
# State table definition.
state_table = {
    ('A', ' '): (' ', 'L', 'B'),
    ('A', '0'): ('0', 'R', 'A'),
    ('A', '1'): ('1', 'R', 'A'),
    ('B', ' '): ('1', 'R', 'C'),
    ('B', '0'): ('1', 'L', 'C'),
    ('B', '1'): ('0', 'L', 'B'),
    ('C', ' '): (' ', 'L', 'HALT'),
    ('C', '0'): ('0', 'R', 'C'),
    ('C', '1'): ('1', 'R', 'C'),
}

def turing_machine(input_str):
    # Tape input.
    tape = list(input_str)
    # Head position on tape.
    head_position = 0
    # Initial state (A).
    state = 'A'

    # Keep executing/looping if state is not in a halting state (HALT).
    while state != 'HALT':
        # If input is not defined for the current state and symbol, return invalid message.
        if (state, tape[head_position]) not in state_table:
            return 'Invalid input'

        # Set symbol, movement and new state from current state.
        new_symbol, move, new_state = state_table[(state, tape[head_position])]
        # Write new symbol.
        tape[head_position] = new_symbol

        # Left and right movement.
        if move == 'L':
            # Insert black symbol if head is at the beginning of tape.
            if head_position == 0:
                tape.insert(0, ' ')
            # Else move left.
            else:
                head_position -= 1
        elif move == 'R':
            # Move right.
            head_position += 1
            # Add a blank symbol if head is at the end of tape.
            if head_position == len(tape):
                tape.append(' ')

        # Set new state.
        state = new_state

    # Return tape output when HALT is reached.
    return ''.join(tape)

# Test the Turing machine.
input_str = '001'
output_str = turing_machine(input_str)
print(output_str)  # Output: '010'
# Out:
# 010

# %% [markdown]
# References: __[Computation](https://github.com/ianmcloughlin/2223-S1-emerging-technologies/blob/main/notebooks/03-computation.ipynb), [Turing Machine in Python](https://python-course.eu/applications-python/turing-machine.php), [Simulating a Turing Machine with Python and executing programs on it](https://sandipanweb.wordpress.com/2020/08/08/simulating-a-turing-machine-with-python-and-executing-programs/)__
#
# ## Polynomial Time Algorithms
# ***
#
# As discussed, an algorithm that takes of $n^{k}$ steps to solve where $k$ is a **non-negative integer** and $n$ is the **input** can be classfied in class P. In addition, any computational problem that is **can be solved in polynomial time with respect to the input size** is considered to be polynomial too. Arithmetic operations (addition, subtraction, multiplication and division), sum of an array and some sorting algorithms such as Selection Sort, Bubble Sort and Insertion Sort algorithms are all in class P.
#
# Below are two examples of algorithms in Python that run in polynomial time.
#
# References: __[Time complexity](https://en.wikipedia.org/wiki/Time_complexity), [Turing Machine in Python](https://www.geeksforgeeks.org/time-complexities-of-all-sorting-algorithms/)__
#
# ### Sum of Array

# %%
# Function to sum array.
def sum_array(arr):
    # Initialise result variable.
    result = 0   
    # Loop through each element in the array.
    for i in arr:
        result += i # Add each element to result.
    return result # Return summed array.

# Test sum_array function.
sum_array([1, 2, 3, 4, 5])
# Out:
# 15

# %% [markdown]
# The first example is a simple and pretty straightforward function to calculate the sum of all elements in an array. The `sum_array` function takes in an array `arr` as an input to sum all elements in the array. Within the function, there is a `for` loop to loop through each element in the array. If the input size is large, the function will take more time to run. Therefore, the time complexity of this algorithm is **proportional to the size of the input**, which is polynomial. To be exact, the complexity of `sum_array` is $O(n)$ where $n$ is the length of the input array.
#
# Reference: __[Python Program to find sum of array](https://www.geeksforgeeks.org/python-program-to-find-sum-of-array/)__
#
# ### Bubble Sort

# %%
# Function to sort a list by comparing and swapping adjacent elements.
def bubble_sort(arr):
    # Get array length.
    n = len(arr)
    
    # Loop through elements from the start of the array,
    # ended at the second last element as it compares with the last element.
    for i in range(n-1):
        # Loop the next element when the previous is sorted,
        # excluding i which is already sorted.
        for j in range(n-i-1):
            # Swap if the current element is greater than the next element.
            if arr[j] > arr[j+1] :
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr # Return sorted array.

arr = [18, 1, 98, 56, 45]
 
print(bubble_sort(arr))
# Out:
# [1, 18, 45, 56, 98]

# %% [markdown]
# The `bubble_sort` function compares and swaps the next element repeatedly if they are in the wrong order, starting from the end. The first `for` loop iterates through the array elements from the first to the second last element as there is no element after the last element. The second loop does the same too, but excludes the ones that have been sorted in previous iterations. The inner loop checks if the current element is greater than the next element, and if it is, swaps them using tuple assignment. The array will be sorted once the outer loop finishes iteration.
#
# This algorithm needs to perform $n * n$ comparisions as it contains two `for` loops to sort the array. This means that bubble sort has a time complexity of $O(n^{2})$, which is also considered as a polynomial time algorithm as it **fulfills the $n^{k}$ rule**. In this case, it is $n^{2}$.
#
# References: __[Bubble Sort](https://www.programiz.com/dsa/bubble-sort), [Python Program for Bubble Sort](https://www.geeksforgeeks.org/python-program-for-bubble-sort/)__
#
# ## Polynomial Time Verification
# ***
#
# Apart from problems in the class P that can be solved in polynomial time, **problems in the class NP** can be **verified in polynomial time** as well, although there is *no known way* to solve the problem in polynomial time. For example, Graph Isomorphism problem is a class NP problem that is yet to be solved in polynomial time but is verifiable in polynomial time.
#
# #### Non-determinism in the class NP
#
# It is worth noting that the term "non-deterministic" in the name of the class NP does not mean that the algorithm used to solve or verify NP problems is non-deterministic. Instead, it means that the algorithm may need to consider multiple possible solutions at the same time to get the optimal solution. This is in contrast to deterministic problems that consider only one possible solution at a time.
#
# References: __[Polynomial Time Verification](https://www.javatpoint.com/daa-polynomial-time-verification), [What is polynomial time verification?](https://www.quora.com/What-is-polynomial-time-verification), [Proof that Subgraph Isomorphism problem is NP-Complete](https://www.geeksforgeeks.org/proof-that-subgraph-isomorphism-problem-is-np-complete/), [Non-Deterministic Algorithm](https://www.techopedia.com/definition/24618/non-deterministic-algorithm#:~:text=Non%2Ddeterministic%20algorithms%20are%20used,by%20the%20algorithm%20during%20execution.)__
